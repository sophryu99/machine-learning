# %%
import requests 
from bs4 import BeautifulSoup

from selenium.webdriver.common.keys import Keys
from selenium import webdriver

import time

# %%
url = 'https://comic.naver.com/webtoon/weekday.nhn'
headers = {'User-Agent': "Mozilla/5.0 (Macintosh; Intel Mac OS X 11_1_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.182 Safari/537.36"}

res = requests.get(url, headers=headers)
# headers 외에도 여러 옵션들이 있지만 그 시간에 selenium을 배우자!
# 나는 로봇이 아닙니다

soup = BeautifulSoup(res.text, "lxml")
# 가져온 html문서를 lxml parser를 통해 Beautifulsoup 객체로 만든 것

# %%
print(soup.title) # title element에서 정보를 다 가져온다.
print(soup.title.get_text()) # title에 있는 text만 빼온다.
print(soup.a) # soup 객체에서 첫 번째로 발견되는 a element를 가져온다.
print(soup.a.attrs) # a element의 attributes들을 보여준다.
print(soup.a["href"])  # a element의 "href" 속성값만 가져온다.
# Out:
# <title>네이버 만화 &gt; 요일별  웹툰 &gt; 전체웹툰</title>
# 네이버 만화 > 요일별  웹툰 > 전체웹툰
# <a href="#menu" onclick="document.getElementById('menu').tabIndex=-1;document.getElementById('menu').focus();return false;"><span>메인 메뉴로 바로가기</span></a>
# {'href': '#menu', 'onclick': "document.getElementById('menu').tabIndex=-1;document.getElementById('menu').focus();return false;"}
# #menu

# %%
import requests
from bs4 import BeautifulSoup

for i in range(1,6):
    url = 'https://comic.naver.com/webtoon/list.nhn?titleId=641253&weekday=sat&page={}'.format(i)
    res = requests.get(url)
    soup = BeautifulSoup(res.text, "lxml")
    # print(soup)
    cartoons = soup.find_all("td", attrs={"class":"title"})   

    for cartoon in cartoons:
        title = cartoon.get_text()
        link = "https://comic.naver.com" + cartoon.a["href"]
        print(title, link)
# Out:
# 327화 클럽 [03]
#
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=327&weekday=sat
#
# 326화 클럽 [02]
#
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=326&weekday=sat
#
# 325화 클럽 [01]
#
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=325&weekday=sat
#
# 324화 원나잇Ⅱ  [마무리]
#
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=324&weekday=sat
#
# 323화 원나잇Ⅱ  [04]
#
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=323&weekday=sat
#
# 322화 원나잇Ⅱ  [03]
#
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=322&weekday=sat
#
# 321화 원나잇Ⅱ  [02]
#
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=321&weekday=sat
#
# 320화 원나잇Ⅱ  [01]
#
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=320&weekday=sat
#
# 319화 일해회 (3계열사) [프롤로그]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=319&weekday=sat
#
# 318화 김기명 [그 후]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=318&weekday=sat
#
# 317화 김기명 [마무리]
#
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=317&weekday=sat
#
# 316화 김기명 [15]
#
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=316&weekday=sat
#
# 315화 김기명 [14]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=315&weekday=sat
#
# 314화 김기명 [13]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=314&weekday=sat
#
# 313화 김기명 [12]
#
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=313&weekday=sat
#
# 312화 김기명 [11]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=312&weekday=sat
#
# 311화 김기명 [10]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=311&weekday=sat
#
# 310화 김기명 [09]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=310&weekday=sat
#
# 309화 김기명 [08]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=309&weekday=sat
#
# 308화 김기명 [07]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=308&weekday=sat
#
# 307화 김기명 [06]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=307&weekday=sat
#
# 306화 김기명 [05]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=306&weekday=sat
#
# 305화 김기명 [04]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=305&weekday=sat
#
# 304화 김기명 [03]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=304&weekday=sat
#
# 303화 김기명 [02]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=303&weekday=sat
#
# 302화 김기명 [01]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=302&weekday=sat
#
# 301화 VS 성요한 [2/2]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=301&weekday=sat
#
# 300화 VS 성요한 [1/2]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=300&weekday=sat
#
# 299화 일해회 (4계열사) [마무리]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=299&weekday=sat
#
# 298화 일해회 (4계열사) [12]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=298&weekday=sat
#
# 297화 일해회 (4계열사) [11]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=297&weekday=sat
#
# 296화 일해회 (4계열사) [10]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=296&weekday=sat
#
# 295화 일해회 (4계열사) [09]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=295&weekday=sat
#
# 294화 일해회 (4계열사) [08]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=294&weekday=sat
#
# 293화 일해회 (4계열사) [07]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=293&weekday=sat
#
# 292화 일해회 (4계열사) [06]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=292&weekday=sat
#
# 291화 일해회 (4계열사) [05]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=291&weekday=sat
#
# 290화 일해회 (4계열사) [04]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=290&weekday=sat
#
# 289화 일해회 (4계열사) [03]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=289&weekday=sat
#
# 288화 일해회 (4계열사) [02]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=288&weekday=sat
#
# 287화 일해회 (4계열사) [01]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=287&weekday=sat
#
# 286화 박형석 VS 종건 [2/2]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=286&weekday=sat
#
# 285화 박형석 VS 종건 [1/2]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=285&weekday=sat
#
# 284화 VS 종건
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=284&weekday=sat
#
# 283화 호스텔 [그 후]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=283&weekday=sat
#
# 282화 호스텔 [마무리]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=282&weekday=sat
#
# 281화 호스텔 [12]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=281&weekday=sat
#
# 280화 호스텔 [11]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=280&weekday=sat
#
# 279화 호스텔 [10]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=279&weekday=sat
#
# 278화 호스텔 [09]
#  https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=278&weekday=sat
